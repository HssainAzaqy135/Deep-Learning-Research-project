# %%
import numpy as np
import pandas as pd
import torch
from torch import nn
from collections import OrderedDict
from torch.utils.data import DataLoader, TensorDataset
from torch.utils.data import ConcatDataset
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# Extras needed
import time
import math
from utils import *

# %% [markdown]
# # Data Genration Functions , Loss for Base Estimator and training and test loops

# %%
def generate_train_test_split(count: int, dim: int, n: int, device: torch.device, coord_max: float, test_size: float = 0.2, seed: int = 42):
    all_batches = generate_vector_batches(count, dim, n, device, coord_max, seed)
    labels = torch.arange(count)  # Placeholder labels if needed

    train_indices, test_indices = train_test_split(range(count), test_size=test_size, random_state=seed)
    train_batches, test_batches = all_batches[train_indices], all_batches[test_indices]

    return train_batches, test_batches

# %%
def create_data_loaders(count, dim, n, device, coord_max, batch_size, test_size=0.2, seed=None):
    # Generate training and testing splits
    train_batches, test_batches = generate_train_test_split(
        count=count, 
        dim=dim, 
        n=n, 
        device=device, 
        coord_max=coord_max, 
        test_size=test_size, 
        seed=seed
    )

    # Create TensorDatasets
    train_dataset = TensorDataset(train_batches)
    test_dataset = TensorDataset(test_batches)

    # Create DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, test_loader

# %%
def make_wass_loss(n: int, d: int):
    def wass_loss(batch, pred):
        # Unpack batched vectors from the input batch
        vecs1 = batch[:, 0, :, :]  # Shape: (batch_size, n, d)
        vecs2 = batch[:, 1, :, :]  # Shape: (batch_size, n, d)

        batch_size = pred.size(0)  # Determine batch size from pred

        # Compute distance matrix for each item in the batch
        total_loss = 0
        for i in range(batch_size):
            distances_mat = torch.cdist(vecs1[i], vecs2[i])  # Shape: (n, n)
            
            # Separate the i-th prediction output into its components
            single_pred = pred[i]
            out_put_mat = single_pred[:n * n].view(n, n)  # Shape: (n, n)
            f = single_pred[n * n:n * n + n]              # Shape: (n,)
            g = single_pred[n * n + n:]                   # Shape: (n,)
            
            # Compute primal and dual solutions for each item in the batch
            sol_prim = primal_sol(out_put_mat=out_put_mat, distances_mat=distances_mat)
            sol_dual = dual_sol(f=f, g=g, distances_mat=distances_mat)

            # Check for NaNs in solutions
            if torch.isnan(sol_prim).any():
                print(f"NaN detected in sol_prim {i}")
            if torch.isnan(sol_dual).any():
                print(f"NaN detected in sol_dual {i}")

            # Accumulate loss
            total_loss += torch.abs(sol_prim - sol_dual)

        # Return average loss across the batch
        return total_loss / batch_size if batch_size > 0 else torch.tensor(0.0, device=pred.device)

    return wass_loss

# %%
def train_model(model, dataloader, loss_fn, optimizer,max_norm = 2.0):
    model.train()
    for batch in dataloader:
        batch = batch[0].to(device)  # Extract batch tensor from DataLoader tuple
        optimizer.zero_grad()

        # Forward pass
        logits = model(batch)
        
        # Compute loss
        loss = loss_fn(batch, logits)
        
        # Backward pass and optimization step
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=max_norm)
        optimizer.step()

def test_model(model, dataloader, loss_fn):
    model.eval()
    total_loss = 0.0
    with torch.no_grad():
        for batch in dataloader:
            batch = batch[0].to(device)
            logits = model(batch)
            loss = loss_fn(batch, logits)
            total_loss += loss.item()
    
    avg_loss = total_loss / len(dataloader)
    return avg_loss

# %%
def plot_losses(train_losses, test_losses):
    """
    Plots average train and test losses against their indices.
    
    Parameters:
    - train_losses (list or array): List or array of average training losses.
    - test_losses (list or array): List or array of average testing losses.
    """
    # Ensure both arrays are the same length
    if len(train_losses) != len(test_losses):
        raise ValueError("train_losses and test_losses must be of the same length.")
    
    indices = range(len(train_losses))
    
    plt.figure(figsize=(12, 5))
    plt.plot(indices, train_losses, label="Average Train Loss", color='blue', marker='o',markersize = 4)
    plt.plot(indices, test_losses, label="Average Test Loss", color='red', marker='x',markersize = 4)
    
    plt.xlabel("Index")
    plt.ylabel("Loss")
    plt.title("Train vs. Test Loss")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def train_and_evaluate(model_class,train_loader,test_loader, d, n, device, batch_size, lr, epochs):
    """
    Train and evaluate a model.

    Parameters:
    - model_class: The model class to be instantiated.
    - train_loader: Training data loader
    - test_loader: Testing data loader
    - d: Dimensionality of the data.
    - n: Number of data points.
    - device: The device to run the model on (e.g., 'cuda' or 'cpu').
    - batch_size: Batch size for training and testing.
    - lr: Learning rate for the optimizer.
    - epochs: Number of training epochs.

    Returns:
    - A list of average test losses per epoch.
    """

    # Initialize model, loss, and optimizer
    model = model_class(n=n, d=d).to(device)
    loss_fn = make_wass_loss(n=n, d=d)
    optimizer = torch.optim.SGD(model.parameters(), lr=lr,momentum=0.95,nesterov=True)

    avg_test_losses = []
    avg_train_losses = []
    # Training and testing loop
    for t in range(epochs):
        print(f"Epoch {t + 1}\n-------------------------------")
        start_time = time.time()
        # Training
        train_model(model, train_loader, loss_fn, optimizer)
        # Testing
        avg_test_losses.append(test_model(model, test_loader, loss_fn))
        avg_train_losses.append(test_model(model, train_loader, loss_fn))
        print(f"Average Train Loss: {avg_train_losses[-1]:.4f}, Average Test Loss: {avg_test_losses[-1]:.4f}")
        end_time = time.time()
        epoch_duration = end_time - start_time
        print(f"Epoch Run time: {epoch_duration:.2f} seconds.\n")
        print("-------------------------------")
    
    print("Done!")
    
    # Return the list of average test losses
    return model,avg_train_losses,avg_test_losses

# %% [markdown]
# # Ensemble Handmade Class

# %%
class Ensemble_Wass(nn.Module):
    def __init__(self, models):
        super(Ensemble_Wass, self).__init__()
        self.models = nn.ModuleList(models)  # Storing the models in a ModuleList for easier parameter management
    def predict_interval(self, x):
        outputs = [model.predict_interval(x) for model in self.models]  # Each model's intervals as a list of tuples

        # Transpose the list of lists to group intervals by index
        intervals_by_index = list(zip(*outputs))

        # Aggregate by taking the max lower bound and min upper bound for each index
        aggregated_output = [
            (min(upper for upper, _ in intervals), max(lower for _, lower in intervals))
            for intervals in intervals_by_index
        ]
        return aggregated_output

# %% [markdown]
# # Base Estimator

# %%
class Base_Wasser_NN(nn.Module):
    def __init__(self, n: int, d: int):
        super().__init__()
        self.n = n
        self.d = d
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(OrderedDict([
            ('Lin1', nn.Linear(2 * n * d, 4 * n * d)),
            ('relu1', nn.ReLU()),
            ('Lin2', nn.Linear(4 * n * d, n * n + 2 * n))  # n x n matrix and two n-long vectors
        ]))

    def forward(self, batch):
        # Reshape batch to (batch_size, 2 * n * d) for the Linear layer
        batch_size = batch.size(0)
        flattened_batch = batch.view(batch_size, 2 * self.n * self.d)  # (batch_size, 2 * n * d)
        
        # Pass through the sequential layers
        logits = self.linear_relu_stack(flattened_batch)
        return logits
    def predict_interval(self, batch):
        # Unpack batched vectors from the input batch
        vecs1 = batch[:, 0, :, :]  # Shape: (batch_size, n, d)
        vecs2 = batch[:, 1, :, :]  # Shape: (batch_size, n, d)

        # Forward pass to get predictions
        pred = self.forward(batch)  # Now expects batched output of shape (batch_size, n * n + 2 * n)
        batch_size = pred.size(0)
        
        results = []
        for i in range(batch_size):
            # Compute distance matrix for the i-th element in the batch
            distances_mat = torch.cdist(vecs1[i], vecs2[i], p=2)  # Shape: (n, n)
    
            # Separate the i-th prediction output into its components
            single_pred = pred[i]
            out_put_mat = single_pred[:n * n].view(n, n)  # Shape: (n, n)
            f = single_pred[n * n:n * n + n]              # Shape: (n,)
            g = single_pred[n * n + n:]                   # Shape: (n,)
    
            # Compute primal and dual solutions
            sol_prim = primal_sol(out_put_mat=out_put_mat, distances_mat=distances_mat)
            sol_dual = dual_sol(f=f, g=g, distances_mat=distances_mat)
            
            # Append the result (sol_prim, sol_dual) for each batch element
            results.append((sol_prim, sol_dual))
        
        return results  # Returns a list of tuples, each containing (sol_prim, sol_dual) for a batch element

# %%
def generate_random_seeds_numpy(k, generation_seed=42, seed_range=(0, 120)):
    np.random.seed(generation_seed)  # Set the seed for reproducibility
    return np.random.randint(seed_range[0], seed_range[1], size=k).tolist()

# %%
def generate_loaders_for_seeds(seed_list, count, d, n, device, coord_max, batch_size, test_size=0.2):
    train_loaders = []
    test_loaders = []

    for seed in seed_list:
        # Generate train and test loaders for the current seed
        train_loader, test_loader = create_data_loaders(
            count=count,
            dim=d,
            n=n,
            device=device,
            coord_max=coord_max,
            batch_size=batch_size,
            test_size=test_size,
            seed=seed
        )
        
        # Append the loaders to their respective lists
        train_loaders.append(train_loader)
        test_loaders.append(test_loader)

    return train_loaders, test_loaders

# %%
def combine_dataloaders(dataloaders, batch_size, shuffle=True):
    """
    Combines multiple DataLoaders into a single DataLoader by concatenating their datasets.

    Args:
        dataloaders (list): List of DataLoaders to combine.
        batch_size (int): Batch size for the combined DataLoader.
        shuffle (bool): Whether to shuffle the data in the combined DataLoader.

    Returns:
        DataLoader: A single DataLoader with all datasets combined.
    """
    # Extract datasets from each DataLoader
    datasets = [dataloader.dataset for dataloader in dataloaders]
    
    # Concatenate all datasets into one
    combined_dataset = ConcatDataset(datasets)
    
    # Create a new DataLoader with the combined dataset
    combined_loader = DataLoader(combined_dataset, batch_size=batch_size, shuffle=shuffle)
    
    return combined_loader

# %%
num_estimators = 5
count = 1000
d = 2
n = 6
seed_list = generate_random_seeds_numpy(k = num_estimators,generation_seed = 42,seed_range=(0, 120))
device = "cpu"
coords_max = 10
lr = 1e-3
batch_size = 32  # Define batch size
epochs = 20

# %%
# Generate lists of DataLoaders
train_loaders, test_loaders = generate_loaders_for_seeds(
    seed_list=seed_list,
    count=count,
    d=d,
    n=n,
    device=device,
    coord_max=coords_max,
    batch_size=batch_size,
    test_size=0.2
)

# %%
combined_train_loader = combine_dataloaders(dataloaders=train_loaders,
                                            batch_size=batch_size,
                                            shuffle=False)
combined_test_loader = combine_dataloaders(dataloaders=test_loaders,
                                            batch_size=batch_size,
                                            shuffle=False)
len(combined_train_loader.dataset),len(combined_test_loader.dataset)
# Out:
# (4000, 1000)

# %% [markdown]
# # Reference pint to a 20 epoch base estimator

# %%
model,avg_train_losses,avg_test_losses = train_and_evaluate(
    model_class=Base_Wasser_NN,
    train_loader = train_loaders[0],
    test_loader=combined_test_loader,
    d=d,
    n=n,
    device=device,
    batch_size=batch_size,
    lr=lr,
    epochs=epochs
)
# Out:
# Epoch 1
# -------------------------------
# Average Train Loss: 26.2316, Average Test Loss: 26.2530
# Epoch Run time: 2.03 seconds.
#
# -------------------------------
# Epoch 2
# -------------------------------
# Average Train Loss: 23.3694, Average Test Loss: 23.5345
# Epoch Run time: 2.02 seconds.
#
# -------------------------------
# Epoch 3
# -------------------------------
# Average Train Loss: 21.7969, Average Test Loss: 22.0777
# Epoch Run time: 2.02 seconds.
#
# -------------------------------
# Epoch 4
# -------------------------------
# Average Train Loss: 20.7210, Average Test Loss: 21.1151
# Epoch Run time: 2.03 seconds.
#
# -------------------------------
# Epoch 5
# -------------------------------
# Average Train Loss: 19.8795, Average Test Loss: 20.3915
# Epoch Run time: 2.04 seconds.
#
# -------------------------------
# Epoch 6
# -------------------------------
# Average Train Loss: 19.1846, Average Test Loss: 19.8079
# Epoch Run time: 2.04 seconds.
#
# -------------------------------
# Epoch 7
# -------------------------------
# Average Train Loss: 18.5834, Average Test Loss: 19.3255
# Epoch Run time: 2.04 seconds.
#
# -------------------------------
# Epoch 8
# -------------------------------
# Average Train Loss: 18.0547, Average Test Loss: 18.9087
# Epoch Run time: 2.06 seconds.
#
# -------------------------------
# Epoch 9
# -------------------------------
# Average Train Loss: 17.5875, Average Test Loss: 18.5391
# Epoch Run time: 2.06 seconds.
#
# -------------------------------
# Epoch 10
# -------------------------------
# Average Train Loss: 17.1700, Average Test Loss: 18.2195
# Epoch Run time: 2.09 seconds.
#
# -------------------------------
# Epoch 11
# -------------------------------
# Average Train Loss: 16.7937, Average Test Loss: 17.9270
# Epoch Run time: 2.04 seconds.
#
# -------------------------------
# Epoch 12
# -------------------------------
# Average Train Loss: 16.4539, Average Test Loss: 17.6695
# Epoch Run time: 2.05 seconds.
#
# -------------------------------
# Epoch 13
# -------------------------------
# Average Train Loss: 16.1385, Average Test Loss: 17.4391
# Epoch Run time: 2.06 seconds.
#
# -------------------------------
# Epoch 14
# -------------------------------
# Average Train Loss: 15.8514, Average Test Loss: 17.2280
# Epoch Run time: 2.02 seconds.
#
# -------------------------------
# Epoch 15
# -------------------------------
# Average Train Loss: 15.5817, Average Test Loss: 17.0294
# Epoch Run time: 2.03 seconds.
#
# -------------------------------
# Epoch 16
# -------------------------------
# Average Train Loss: 15.3359, Average Test Loss: 16.8535
# Epoch Run time: 2.08 seconds.
#
# -------------------------------
# Epoch 17
# -------------------------------
# Average Train Loss: 15.1089, Average Test Loss: 16.6886
# Epoch Run time: 2.01 seconds.
#
# -------------------------------
# Epoch 18
# -------------------------------
# Average Train Loss: 14.8942, Average Test Loss: 16.5316
# Epoch Run time: 1.98 seconds.
#
# -------------------------------
# Epoch 19
# -------------------------------
# Average Train Loss: 14.6947, Average Test Loss: 16.3880
# Epoch Run time: 2.03 seconds.
#
# -------------------------------
# Epoch 20
# -------------------------------
# Average Train Loss: 14.5123, Average Test Loss: 16.2561
# Epoch Run time: 2.04 seconds.
#
# -------------------------------
# Done!

# %% [markdown]
# # Saving this reference base model

# %%
model_path = "Trained_models/Ensemble_Reference_Base_net_20_ep_1000_data.pt"

# %%
torch.save(model.state_dict(), model_path)

# %%
# Loading the model
model = Base_Wasser_NN(n=n, d=d).to(device)
model.load_state_dict(torch.load(model_path))
model.eval()
print("Model loaded successfully.")
# Out:
# Model loaded successfully.

# %% [markdown]
# # Plot reference losses

# %%
plot_losses(avg_train_losses,avg_test_losses)

# %%
def train_k_models(base_model_class,train_loaders,test_loader):
    models = []
    train_losses_list = []
    test_losses_list = []
    for i in range(len(train_loaders)):
        print("<><><><><><><><><><><><><><><><><><><><><><><><><><><><>")
        print(f"Training model Number {i}")
        print("<><><><><><><><><><><><><><><><><><><><><><><><><><><><>")
        model,avg_train_losses,avg_test_losses = train_and_evaluate(
        model_class=base_model_class,
        train_loader = train_loaders[i],
        test_loader=test_loader,
        d=d,
        n=n,
        device=device,
        batch_size=batch_size,
        lr=lr,
        epochs=epochs
        )
        models.append(model)
        train_losses_list.append(avg_train_losses)
        test_losses_list.append(avg_test_losses)
        print("<><><><><><><><><><><><><><><><><><><><><><><><><><><><>")
    return models,train_losses_list,test_losses_list

# %%
models,train_losses_list,test_losses_list = train_k_models(base_model_class = Base_Wasser_NN,
                                                           train_loaders = train_loaders,
                                                           test_loader = combined_test_loader)
# Out:
# <><><><><><><><><><><><><><><><><><><><><><><><><><><><>
# Training model Number 0
# <><><><><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch 1
# -------------------------------
# Average Train Loss: 24.8013, Average Test Loss: 24.9284
# Epoch Run time: 2.01 seconds.
#
# -------------------------------
# Epoch 2
# -------------------------------
# Average Train Loss: 22.7190, Average Test Loss: 22.9256
# Epoch Run time: 2.12 seconds.
#
# -------------------------------
# Epoch 3
# -------------------------------
# Average Train Loss: 21.3826, Average Test Loss: 21.7184
# Epoch Run time: 2.01 seconds.
#
# -------------------------------
# Epoch 4
# -------------------------------
# Average Train Loss: 20.4063, Average Test Loss: 20.8716
# Epoch Run time: 1.97 seconds.
#
# -------------------------------
# Epoch 5
# -------------------------------
# Average Train Loss: 19.6151, Average Test Loss: 20.2064
# Epoch Run time: 2.01 seconds.
#
# -------------------------------
# Epoch 6
# -------------------------------
# Average Train Loss: 18.9527, Average Test Loss: 19.6511
# Epoch Run time: 2.02 seconds.
#
# -------------------------------
# Epoch 7
# -------------------------------
# Average Train Loss: 18.3750, Average Test Loss: 19.1675
# Epoch Run time: 2.04 seconds.
#
# -------------------------------
# Epoch 8
# -------------------------------
# Average Train Loss: 17.8581, Average Test Loss: 18.7362
# Epoch Run time: 2.08 seconds.
#
# -------------------------------
# Epoch 9
# -------------------------------
# Average Train Loss: 17.3918, Average Test Loss: 18.3604
# Epoch Run time: 2.02 seconds.
#
# -------------------------------
# Epoch 10
# -------------------------------
# Average Train Loss: 16.9717, Average Test Loss: 18.0295
# Epoch Run time: 2.03 seconds.
#
# -------------------------------
# Epoch 11
# -------------------------------
# Average Train Loss: 16.5917, Average Test Loss: 17.7305
# Epoch Run time: 2.02 seconds.
#
# -------------------------------
# Epoch 12
# -------------------------------
# Average Train Loss: 16.2452, Average Test Loss: 17.4635
# Epoch Run time: 2.01 seconds.
#
# -------------------------------
# Epoch 13
# -------------------------------
# Average Train Loss: 15.9272, Average Test Loss: 17.2234
# Epoch Run time: 2.00 seconds.
#
# -------------------------------
# Epoch 14
# -------------------------------
# Average Train Loss: 15.6415, Average Test Loss: 17.0072
# Epoch Run time: 2.02 seconds.
#
# -------------------------------
# Epoch 15
# -------------------------------
# Average Train Loss: 15.3765, Average Test Loss: 16.8147
# Epoch Run time: 2.06 seconds.
#
# -------------------------------
# Epoch 16
# -------------------------------
# Average Train Loss: 15.1329, Average Test Loss: 16.6396
# Epoch Run time: 2.05 seconds.
#
# -------------------------------
# Epoch 17
# -------------------------------
# Average Train Loss: 14.9140, Average Test Loss: 16.4900
# Epoch Run time: 2.03 seconds.
#
# -------------------------------
# Epoch 18
# -------------------------------
# Average Train Loss: 14.7019, Average Test Loss: 16.3326
# Epoch Run time: 2.02 seconds.
#
# -------------------------------
# Epoch 19
# -------------------------------
# Average Train Loss: 14.5007, Average Test Loss: 16.1976
# Epoch Run time: 2.01 seconds.
#
# -------------------------------
# Epoch 20
# -------------------------------
# Average Train Loss: 14.3204, Average Test Loss: 16.0745
# Epoch Run time: 2.06 seconds.
#
# -------------------------------
# Done!
# <><><><><><><><><><><><><><><><><><><><><><><><><><><><>
# <><><><><><><><><><><><><><><><><><><><><><><><><><><><>
# Training model Number 1
# <><><><><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch 1
# -------------------------------
# Average Train Loss: 25.6716, Average Test Loss: 25.7089
# Epoch Run time: 1.97 seconds.
#
# -------------------------------
# Epoch 2
# -------------------------------
# Average Train Loss: 23.0853, Average Test Loss: 23.2279
# Epoch Run time: 2.05 seconds.
#
# -------------------------------
# Epoch 3
# -------------------------------
# Average Train Loss: 21.6142, Average Test Loss: 21.8714
# Epoch Run time: 2.13 seconds.
#
# -------------------------------
# Epoch 4
# -------------------------------
# Average Train Loss: 20.5828, Average Test Loss: 20.9513
# Epoch Run time: 2.08 seconds.
#
# -------------------------------
# Epoch 5
# -------------------------------
# Average Train Loss: 19.7731, Average Test Loss: 20.2546
# Epoch Run time: 2.13 seconds.
#
# -------------------------------
# Epoch 6
# -------------------------------
# Average Train Loss: 19.0858, Average Test Loss: 19.6769
# Epoch Run time: 2.06 seconds.
#
# -------------------------------
# Epoch 7
# -------------------------------
# Average Train Loss: 18.4985, Average Test Loss: 19.1850
# Epoch Run time: 2.13 seconds.
#
# -------------------------------
# Epoch 8
# -------------------------------
# Average Train Loss: 17.9766, Average Test Loss: 18.7599
# Epoch Run time: 2.08 seconds.
#
# -------------------------------
# Epoch 9
# -------------------------------
# Average Train Loss: 17.5166, Average Test Loss: 18.3880
# Epoch Run time: 2.12 seconds.
#
# -------------------------------
# Epoch 10
# -------------------------------
# Average Train Loss: 17.0888, Average Test Loss: 18.0448
# Epoch Run time: 2.19 seconds.
#
# -------------------------------
# Epoch 11
# -------------------------------
# Average Train Loss: 16.7009, Average Test Loss: 17.7382
# Epoch Run time: 2.12 seconds.
#
# -------------------------------
# Epoch 12
# -------------------------------
# Average Train Loss: 16.3485, Average Test Loss: 17.4638
# Epoch Run time: 2.02 seconds.
#
# -------------------------------
# Epoch 13
# -------------------------------
# Average Train Loss: 16.0226, Average Test Loss: 17.2221
# Epoch Run time: 2.15 seconds.
#
# -------------------------------
# Epoch 14
# -------------------------------
# Average Train Loss: 15.7237, Average Test Loss: 17.0004
# Epoch Run time: 2.11 seconds.
#
# -------------------------------
# Epoch 15
# -------------------------------
# Average Train Loss: 15.4487, Average Test Loss: 16.7980
# Epoch Run time: 2.09 seconds.
#
# -------------------------------
# Epoch 16
# -------------------------------
# Average Train Loss: 15.1917, Average Test Loss: 16.6184
# Epoch Run time: 2.06 seconds.
#
# -------------------------------
# Epoch 17
# -------------------------------
# Average Train Loss: 14.9553, Average Test Loss: 16.4488
# Epoch Run time: 2.11 seconds.
#
# -------------------------------
# Epoch 18
# -------------------------------
# Average Train Loss: 14.7360, Average Test Loss: 16.2937
# Epoch Run time: 2.08 seconds.
#
# -------------------------------
# Epoch 19
# -------------------------------
# Average Train Loss: 14.5336, Average Test Loss: 16.1644
# Epoch Run time: 2.08 seconds.
#
# -------------------------------
# Epoch 20
# -------------------------------
# Average Train Loss: 14.3464, Average Test Loss: 16.0355
# Epoch Run time: 2.04 seconds.
#
# -------------------------------
# Done!
# <><><><><><><><><><><><><><><><><><><><><><><><><><><><>
# <><><><><><><><><><><><><><><><><><><><><><><><><><><><>
# Training model Number 2
# <><><><><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch 1
# -------------------------------
# Average Train Loss: 25.2881, Average Test Loss: 25.5090
# Epoch Run time: 2.02 seconds.
#
# -------------------------------
# Epoch 2
# -------------------------------
# Average Train Loss: 22.8597, Average Test Loss: 23.1537
# Epoch Run time: 1.96 seconds.
#
# -------------------------------
# Epoch 3
# -------------------------------
# Average Train Loss: 21.4471, Average Test Loss: 21.8579
# Epoch Run time: 2.04 seconds.
#
# -------------------------------
# Epoch 4
# -------------------------------
# Average Train Loss: 20.4226, Average Test Loss: 20.9636
# Epoch Run time: 1.99 seconds.
#
# -------------------------------
# Epoch 5
# -------------------------------
# Average Train Loss: 19.6071, Average Test Loss: 20.2678
# Epoch Run time: 2.02 seconds.
#
# -------------------------------
# Epoch 6
# -------------------------------
# Average Train Loss: 18.9157, Average Test Loss: 19.6903
# Epoch Run time: 2.01 seconds.
#
# -------------------------------
# Epoch 7
# -------------------------------
# Average Train Loss: 18.3006, Average Test Loss: 19.1889
# Epoch Run time: 2.02 seconds.
#
# -------------------------------
# Epoch 8
# -------------------------------
# Average Train Loss: 17.7655, Average Test Loss: 18.7502
# Epoch Run time: 2.01 seconds.
#
# -------------------------------
# Epoch 9
# -------------------------------
# Average Train Loss: 17.3009, Average Test Loss: 18.3748
# Epoch Run time: 1.99 seconds.
#
# -------------------------------
# Epoch 10
# -------------------------------
# Average Train Loss: 16.8766, Average Test Loss: 18.0375
# Epoch Run time: 2.00 seconds.
#
# -------------------------------
# Epoch 11
# -------------------------------
# Average Train Loss: 16.5008, Average Test Loss: 17.7529
# Epoch Run time: 1.97 seconds.
#
# -------------------------------
# Epoch 12
# -------------------------------
# Average Train Loss: 16.1553, Average Test Loss: 17.4843
# Epoch Run time: 2.00 seconds.
#
# -------------------------------
# Epoch 13
# -------------------------------
# Average Train Loss: 15.8485, Average Test Loss: 17.2469
# Epoch Run time: 2.09 seconds.
#
# -------------------------------
# Epoch 14
# -------------------------------
# Average Train Loss: 15.5618, Average Test Loss: 17.0383
# Epoch Run time: 2.00 seconds.
#
# -------------------------------
# Epoch 15
# -------------------------------
# Average Train Loss: 15.2955, Average Test Loss: 16.8394
# Epoch Run time: 2.09 seconds.
#
# -------------------------------
# Epoch 16
# -------------------------------
# Average Train Loss: 15.0587, Average Test Loss: 16.6619
# Epoch Run time: 2.01 seconds.
#
# -------------------------------
# Epoch 17
# -------------------------------
# Average Train Loss: 14.8383, Average Test Loss: 16.5009
# Epoch Run time: 2.04 seconds.
#
# -------------------------------
# Epoch 18
# -------------------------------
# Average Train Loss: 14.6337, Average Test Loss: 16.3538
# Epoch Run time: 2.13 seconds.
#
# -------------------------------
# Epoch 19
# -------------------------------
# Average Train Loss: 14.4471, Average Test Loss: 16.2107
# Epoch Run time: 2.02 seconds.
#
# -------------------------------
# Epoch 20
# -------------------------------
# Average Train Loss: 14.2728, Average Test Loss: 16.0910
# Epoch Run time: 2.07 seconds.
#
# -------------------------------
# Done!
# <><><><><><><><><><><><><><><><><><><><><><><><><><><><>
# <><><><><><><><><><><><><><><><><><><><><><><><><><><><>
# Training model Number 3
# <><><><><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch 1
# -------------------------------
# Average Train Loss: 25.0333, Average Test Loss: 25.2178
# Epoch Run time: 2.00 seconds.
#
# -------------------------------
# Epoch 2
# -------------------------------
# Average Train Loss: 22.8045, Average Test Loss: 23.0464
# Epoch Run time: 2.00 seconds.
#
# -------------------------------
# Epoch 3
# -------------------------------
# Average Train Loss: 21.4410, Average Test Loss: 21.7935
# Epoch Run time: 2.00 seconds.
#
# -------------------------------
# Epoch 4
# -------------------------------
# Average Train Loss: 20.4525, Average Test Loss: 20.9297
# Epoch Run time: 2.00 seconds.
#
# -------------------------------
# Epoch 5
# -------------------------------
# Average Train Loss: 19.6545, Average Test Loss: 20.2479
# Epoch Run time: 2.01 seconds.
#
# -------------------------------
# Epoch 6
# -------------------------------
# Average Train Loss: 18.9849, Average Test Loss: 19.7024
# Epoch Run time: 2.00 seconds.
#
# -------------------------------
# Epoch 7
# -------------------------------
# Average Train Loss: 18.3968, Average Test Loss: 19.2275
# Epoch Run time: 2.02 seconds.
#
# -------------------------------
# Epoch 8
# -------------------------------
# Average Train Loss: 17.8758, Average Test Loss: 18.8170
# Epoch Run time: 2.00 seconds.
#
# -------------------------------
# Epoch 9
# -------------------------------
# Average Train Loss: 17.4085, Average Test Loss: 18.4534
# Epoch Run time: 1.99 seconds.
#
# -------------------------------
# Epoch 10
# -------------------------------
# Average Train Loss: 16.9888, Average Test Loss: 18.1321
# Epoch Run time: 2.00 seconds.
#
# -------------------------------
# Epoch 11
# -------------------------------
# Average Train Loss: 16.6033, Average Test Loss: 17.8363
# Epoch Run time: 1.98 seconds.
#
# -------------------------------
# Epoch 12
# -------------------------------
# Average Train Loss: 16.2529, Average Test Loss: 17.5804
# Epoch Run time: 2.01 seconds.
#
# -------------------------------
# Epoch 13
# -------------------------------
# Average Train Loss: 15.9291, Average Test Loss: 17.3413
# Epoch Run time: 1.98 seconds.
#
# -------------------------------
# Epoch 14
# -------------------------------
# Average Train Loss: 15.6294, Average Test Loss: 17.1289
# Epoch Run time: 2.09 seconds.
#
# -------------------------------
# Epoch 15
# -------------------------------
# Average Train Loss: 15.3543, Average Test Loss: 16.9267
# Epoch Run time: 2.06 seconds.
#
# -------------------------------
# Epoch 16
# -------------------------------
# Average Train Loss: 15.0995, Average Test Loss: 16.7455
# Epoch Run time: 2.01 seconds.
#
# -------------------------------
# Epoch 17
# -------------------------------
# Average Train Loss: 14.8639, Average Test Loss: 16.5784
# Epoch Run time: 2.00 seconds.
#
# -------------------------------
# Epoch 18
# -------------------------------
# Average Train Loss: 14.6414, Average Test Loss: 16.4227
# Epoch Run time: 2.02 seconds.
#
# -------------------------------
# Epoch 19
# -------------------------------
# Average Train Loss: 14.4315, Average Test Loss: 16.2697
# Epoch Run time: 2.04 seconds.
#
# -------------------------------
# Epoch 20
# -------------------------------
# Average Train Loss: 14.2396, Average Test Loss: 16.1344
# Epoch Run time: 2.09 seconds.
#
# -------------------------------
# Done!
# <><><><><><><><><><><><><><><><><><><><><><><><><><><><>
# <><><><><><><><><><><><><><><><><><><><><><><><><><><><>
# Training model Number 4
# <><><><><><><><><><><><><><><><><><><><><><><><><><><><>
# Epoch 1
# -------------------------------
# Average Train Loss: 25.0426, Average Test Loss: 25.2013
# Epoch Run time: 1.98 seconds.
#
# -------------------------------
# Epoch 2
# -------------------------------
# Average Train Loss: 22.8380, Average Test Loss: 23.0438
# Epoch Run time: 1.99 seconds.
#
# -------------------------------
# Epoch 3
# -------------------------------
# Average Train Loss: 21.4809, Average Test Loss: 21.7975
# Epoch Run time: 1.98 seconds.
#
# -------------------------------
# Epoch 4
# -------------------------------
# Average Train Loss: 20.4959, Average Test Loss: 20.9299
# Epoch Run time: 2.03 seconds.
#
# -------------------------------
# Epoch 5
# -------------------------------
# Average Train Loss: 19.7096, Average Test Loss: 20.2532
# Epoch Run time: 2.00 seconds.
#
# -------------------------------
# Epoch 6
# -------------------------------
# Average Train Loss: 19.0444, Average Test Loss: 19.6943
# Epoch Run time: 1.99 seconds.
#
# -------------------------------
# Epoch 7
# -------------------------------
# Average Train Loss: 18.4728, Average Test Loss: 19.2238
# Epoch Run time: 1.97 seconds.
#
# -------------------------------
# Epoch 8
# -------------------------------
# Average Train Loss: 17.9594, Average Test Loss: 18.8073
# Epoch Run time: 1.97 seconds.
#
# -------------------------------
# Epoch 9
# -------------------------------
# Average Train Loss: 17.4971, Average Test Loss: 18.4395
# Epoch Run time: 2.04 seconds.
#
# -------------------------------
# Epoch 10
# -------------------------------
# Average Train Loss: 17.0843, Average Test Loss: 18.1230
# Epoch Run time: 2.04 seconds.
#
# -------------------------------
# Epoch 11
# -------------------------------
# Average Train Loss: 16.7122, Average Test Loss: 17.8330
# Epoch Run time: 2.04 seconds.
#
# -------------------------------
# Epoch 12
# -------------------------------
# Average Train Loss: 16.3752, Average Test Loss: 17.5798
# Epoch Run time: 2.02 seconds.
#
# -------------------------------
# Epoch 13
# -------------------------------
# Average Train Loss: 16.0691, Average Test Loss: 17.3552
# Epoch Run time: 1.99 seconds.
#
# -------------------------------
# Epoch 14
# -------------------------------
# Average Train Loss: 15.7917, Average Test Loss: 17.1462
# Epoch Run time: 2.02 seconds.
#
# -------------------------------
# Epoch 15
# -------------------------------
# Average Train Loss: 15.5320, Average Test Loss: 16.9545
# Epoch Run time: 2.01 seconds.
#
# -------------------------------
# Epoch 16
# -------------------------------
# Average Train Loss: 15.2806, Average Test Loss: 16.7789
# Epoch Run time: 2.01 seconds.
#
# -------------------------------
# Epoch 17
# -------------------------------
# Average Train Loss: 15.0499, Average Test Loss: 16.6137
# Epoch Run time: 2.00 seconds.
#
# -------------------------------
# Epoch 18
# -------------------------------
# Average Train Loss: 14.8349, Average Test Loss: 16.4678
# Epoch Run time: 2.05 seconds.
#
# -------------------------------
# Epoch 19
# -------------------------------
# Average Train Loss: 14.6357, Average Test Loss: 16.3301
# Epoch Run time: 2.01 seconds.
#
# -------------------------------
# Epoch 20
# -------------------------------
# Average Train Loss: 14.4509, Average Test Loss: 16.2029
# Epoch Run time: 1.98 seconds.
#
# -------------------------------
# Done!
# <><><><><><><><><><><><><><><><><><><><><><><><><><><><>

# %%
models
# Out:
# [Base_Wasser_NN(
#    (flatten): Flatten(start_dim=1, end_dim=-1)
#    (linear_relu_stack): Sequential(
#      (Lin1): Linear(in_features=24, out_features=48, bias=True)
#      (relu1): ReLU()
#      (Lin2): Linear(in_features=48, out_features=48, bias=True)
#    )
#  ),
#  Base_Wasser_NN(
#    (flatten): Flatten(start_dim=1, end_dim=-1)
#    (linear_relu_stack): Sequential(
#      (Lin1): Linear(in_features=24, out_features=48, bias=True)
#      (relu1): ReLU()
#      (Lin2): Linear(in_features=48, out_features=48, bias=True)
#    )
#  ),
#  Base_Wasser_NN(
#    (flatten): Flatten(start_dim=1, end_dim=-1)
#    (linear_relu_stack): Sequential(
#      (Lin1): Linear(in_features=24, out_features=48, bias=True)
#      (relu1): ReLU()
#      (Lin2): Linear(in_features=48, out_features=48, bias=True)
#    )
#  ),
#  Base_Wasser_NN(
#    (flatten): Flatten(start_dim=1, end_dim=-1)
#    (linear_relu_stack): Sequential(
#      (Lin1): Linear(in_features=24, out_features=48, bias=True)
#      (relu1): ReLU()
#      (Lin2): Linear(in_features=48, out_features=48, bias=True)
#    )
#  ),
#  Base_Wasser_NN(
#    (flatten): Flatten(start_dim=1, end_dim=-1)
#    (linear_relu_stack): Sequential(
#      (Lin1): Linear(in_features=24, out_features=48, bias=True)
#      (relu1): ReLU()
#      (Lin2): Linear(in_features=48, out_features=48, bias=True)
#    )
#  )]

# %% [markdown]
# # Saving models list

# %%
model_path = "Trained_models/Ensemble_base_estimator_Base_net_20_ep_1000_data_number_"

# %%
for i in range(num_estimators):
    torch.save(model.state_dict(), model_path+f"{i}.pt")

# %%
models = []
for i in range(num_estimators):
    # Loading the model
    model = Base_Wasser_NN(n=n, d=d).to(device)
    model.load_state_dict(torch.load(model_path+f"{i}.pt"))
    model.eval()
    models.append(model)
    print(f"Model {i} loaded successfully.")
# Out:
# Model 0 loaded successfully.
# Model 1 loaded successfully.
# Model 2 loaded successfully.
# Model 3 loaded successfully.
# Model 4 loaded successfully.

# %% [markdown]
# # Trying the ensemble model

# %%
ensemble_model = Ensemble_Wass(models)

# %%
ensemble_model.models
# Out:
# ModuleList(
#   (0-4): 5 x Base_Wasser_NN(
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#     (linear_relu_stack): Sequential(
#       (Lin1): Linear(in_features=24, out_features=48, bias=True)
#       (relu1): ReLU()
#       (Lin2): Linear(in_features=48, out_features=48, bias=True)
#     )
#   )
# )

# %%
def test_ensemble_model(model, dataloader):
    model.eval()
    for sub_model in model.models:
        sub_model.eval()
    total_loss = 0.0
    with torch.no_grad():
        for batch in dataloader:
            batch = batch[0].to(device)
            preds = model.predict_interval(batch)
            total_loss += np.mean([(dual.item() -primal.item()) for (dual,primal) in preds])
    
    avg_loss = total_loss / len(dataloader)
    return avg_loss

# %%
def evaluate_ensemble(model,train_loader,test_loader):
    avg_test_losses = (test_ensemble_model(model, test_loader))
    avg_train_losses = (test_ensemble_model(model, train_loader))
    print(f"Average Train Loss: {avg_train_losses:.4f}, Average Test Loss: {avg_test_losses:.4f}")

# %%
evaluate_ensemble(model = ensemble_model,
                 train_loader=combined_train_loader,
                 test_loader=combined_test_loader)
# Out:
# Average Train Loss: 15.9108, Average Test Loss: 16.2561

# %%
total_final_losses_test = []
for i in range(num_estimators):
    print(test_losses_list[i][-1])
    total_final_losses_test.append(test_losses_list[i][-1])
print(f"Average final test loss for base estimators: {np.mean(total_final_losses_test)}")

total_final_losses_train = []
for i in range(num_estimators):
    print(train_losses_list[i][-1])
    total_final_losses_train.append(train_losses_list[i][-1])
print(f"Average final test loss for base estimators: {np.mean(total_final_losses_train)}")
# Out:
# 16.07452693581581
# 16.035459369421005
# 16.09097597002983
# 16.13435608148575
# 16.202938348054886
# Average final test loss for base estimators: 16.107651340961457
# 14.320399475097656
# 14.346360664367676
# 14.272817306518554
# 14.239596061706543
# 14.45088535308838
# Average final test loss for base estimators: 14.326011772155761
